# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Name = "Alex Alexa"
age = 25

# %%
print(type(Name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Current_Year = 2024
Year = input("please enter your DOB year ")
Age = Current_Year - Year
print(Age)
# Out:
# please enter your DOB year 2001
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 Current_Year = 2024
#       2 Year = input("please enter your DOB year ")
# ----> 3 Age = Current_Year - Year
#       4 print(Age)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
#solution
Current_Year = 2024
Year = int(input("please enter your DOB year "))
Age = Current_Year - Year
print(Age)
# Out:
# please enter your DOB year2001
# 23

# %%
#solution
Current_Year = 2024
Year = input("please enter your DOB year ")
Year = int(Year)
Age = Current_Year - Year
print(Age)
# Out:
# please enter your DOB year2001
# 23
