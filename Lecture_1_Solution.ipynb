# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
Yellow_bag_price = 4
Total_bag_number = 4

Total_Money_Required = Yellow_bag_price * total_bag_number
print(Total_Money_Required)
# Out:
# 16

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Total_bag_number = 7
Stole_bag = 3

Total_Bag_Left = Total_bag_number - Stole_bag
print(Total_Bag_Left)
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Total_bag_number = 12
People_number = 3

Distributed_bags = Total_bag_number / People_number
print(Distributed_bags)
# Out:
# 4.0
